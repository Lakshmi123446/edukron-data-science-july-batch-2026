# %%
a = "Edukron Data Science and Data Engineering Batch 2026"
print(a[0:7])
print(a[8:12])
print(a[13:20])
print(a[21:24])
print(a[25:41])
print(a[30:41])
print(a[42:47])
print(a[48:52])
print(a[13:29])
print(a[8:47])
print(a[-52:-45])
print(a[-44:-40])
print(a[-39:-32])
print(a[-31:-28])
print(a[-27:-11])
print(a[-22:-11])
print(a[-10:-5])
print(a[-4:])
print(a[-39:-23])
print(a[-44:-5])
# Out:
# Edukron
# Data
# Science
# and
# Data Engineering
# Engineering
# Batch
# 2026
# Science and Data
# Data Science and Data Engineering Batch
# Edukron
# Data
# Science
# and
# Data Engineering
# Engineering
# Batch
# 2026
# Science and Data
# Data Science and Data Engineering Batch

# %%
a[0:8]
# Out:
# 'Edukron '
